# %%
pip install bs4

# %%
pip install requests

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.imdb.com/list/ls025925744/"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>25 Best movies of Suriya - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls025925744/" rel="canonical"/>
# ...

# %%
name=soup.select(".lister-item-header a")

# %%
name
# Out:
# [<a href="/title/tt10189514/">Soorarai Pottru</a>,
#  <a href="/title/tt15097216/">Jai Bhim</a>,
#  <a href="/title/tt1180583/">Vaaranam Aayiram</a>,
#  <a href="/title/tt0375997/">Nandha</a>,
#  <a href="/title/tt4981966/">24</a>,
#  <a href="/title/tt0449951/">Ghajini</a>,
#  <a href="/title/tt0375878/">Kaakha..Kaakha: The Police</a>,
#  <a href="/title/tt1355546/">Ayan</a>,
#  <a href="/title/tt0386650/">Mounam Pesiyadhe</a>,
#  <a href="/title/tt1655607/">Singam</a>,
#  <a href="/title/tt0376076/">Pithamagan</a>,
#  <a href="/title/tt1725795/">7 Aum Arivu</a>,
#  <a href="/title/tt0375571/">Ayitha Ezhuthu</a>,
#  <a href="/title/tt6358182/">Unnai Ninaithu</a>,
#  <a href="/title/tt5285050/">Pasanga 2</a>,
#  <a href="/title/tt2246837/">Maattrraan</a>,
#  <a href="/title/tt0464071/">Sillunu Oru Kadhal</a>,
#  <a href="/title/tt0422934/">Peralagan</a>,
#  <a href="/title/tt0417011/">Nerukku Ner</a>,
#  <a href="/title/tt5323640/">Singam 3</a>,
# ...

# %%
rates=soup.select(".ipl-rating-star.small .ipl-rating-star__rating")

# %%
rates
# Out:
# [<span class="ipl-rating-star__rating">8.7</span>,
#  <span class="ipl-rating-star__rating">8.9</span>,
#  <span class="ipl-rating-star__rating">8.2</span>,
#  <span class="ipl-rating-star__rating">7.7</span>,
#  <span class="ipl-rating-star__rating">7.9</span>,
#  <span class="ipl-rating-star__rating">7.5</span>,
#  <span class="ipl-rating-star__rating">8</span>,
#  <span class="ipl-rating-star__rating">7.6</span>,
#  <span class="ipl-rating-star__rating">7.7</span>,
#  <span class="ipl-rating-star__rating">6.9</span>,
#  <span class="ipl-rating-star__rating">8.3</span>,
#  <span class="ipl-rating-star__rating">6.5</span>,
#  <span class="ipl-rating-star__rating">7.9</span>,
#  <span class="ipl-rating-star__rating">7.3</span>,
#  <span class="ipl-rating-star__rating">7.3</span>,
#  <span class="ipl-rating-star__rating">6.1</span>,
#  <span class="ipl-rating-star__rating">7</span>,
#  <span class="ipl-rating-star__rating">6.4</span>,
# ...

# %%
import pandas as pd

# %%
suriyamovie=pd.DataFrame(name,columns=["list"])

# %%
suriyamovie
# Out:
#                           list
# 0              Soorarai Pottru
# 1                     Jai Bhim
# 2             Vaaranam Aayiram
# 3                       Nandha
# 4                           24
# 5                      Ghajini
# 6   Kaakha..Kaakha: The Police
# 7                         Ayan
# 8             Mounam Pesiyadhe
# 9                       Singam
# 10                  Pithamagan
# 11                 7 Aum Arivu
# 12              Ayitha Ezhuthu
# 13              Unnai Ninaithu
# 14                   Pasanga 2
# 15                  Maattrraan
# 16          Sillunu Oru Kadhal
# 17                   Peralagan
# 18                 Nerukku Ner
# 19                    Singam 3
# 20                     Friends
# 21             Rakhta Charitra
# 22                    Singam 2
# 23     Thaanaa Serndha Koottam
# 24                       Masss

# %%
suriyamovie["ratings"]=rates

# %%
suriyamovie
# Out:
#                           list ratings
# 0              Soorarai Pottru   [8.7]
# 1                     Jai Bhim   [8.9]
# 2             Vaaranam Aayiram   [8.2]
# 3                       Nandha   [7.7]
# 4                           24   [7.9]
# 5                      Ghajini   [7.5]
# 6   Kaakha..Kaakha: The Police     [8]
# 7                         Ayan   [7.6]
# 8             Mounam Pesiyadhe   [7.7]
# 9                       Singam   [6.9]
# 10                  Pithamagan   [8.3]
# 11                 7 Aum Arivu   [6.5]
# 12              Ayitha Ezhuthu   [7.9]
# 13              Unnai Ninaithu   [7.3]
# 14                   Pasanga 2   [7.3]
# 15                  Maattrraan   [6.1]
# 16          Sillunu Oru Kadhal     [7]
# 17                   Peralagan   [6.4]
# 18                 Nerukku Ner   [7.5]
# 19                    Singam 3     [6]
# 20                     Friends   [7.9]
# 21             Rakhta Charitra   [7.6]
# 22                    Singam 2   [6.3]
# ...

# %%
suriyamovie.to_csv("D:\sweety1.csv")

# %%
table2=pd.read_csv("D:\sweety1.csv")

# %%
table2
# Out:
#     Unnamed: 0                        list  \
# 0            0             Soorarai Pottru
# 1            1                    Jai Bhim
# 2            2            Vaaranam Aayiram
# 3            3                      Nandha
# 4            4                          24
# 5            5                     Ghajini
# 6            6  Kaakha..Kaakha: The Police
# 7            7                        Ayan
# 8            8            Mounam Pesiyadhe
# 9            9                      Singam
# 10          10                  Pithamagan
# 11          11                 7 Aum Arivu
# 12          12              Ayitha Ezhuthu
# 13          13              Unnai Ninaithu
# 14          14                   Pasanga 2
# 15          15                  Maattrraan
# 16          16          Sillunu Oru Kadhal
# 17          17                   Peralagan
# 18          18                 Nerukku Ner
# 19          19                    Singam 3
# 20          20                     Friends
# ...

# %%
table2["ratings"]=table2["ratings"]str.strip(<span class="ipl-rating-star__rating">)
# Out:
#   Cell In [2], line 1
#     table2["ratings"]=table2["ratings"]str.strip(<span class="ipl-rating-star__rating">)
#                                        ^
# SyntaxError: invalid syntax
